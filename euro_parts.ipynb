# %%
print(7)
# final_daily_sales
# Out:
# 7

# %%
from sqlalchemy import create_engine

DB_USER = "muhammad-haroon"
DB_PASS = "haroon123"
DB_HOST = "localhost"      # or server IP
DB_PORT = "5432"
DB_NAME = "euro_parts_data"

engine = create_engine(
    f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

# %%
engine
# Out:
# Engine(postgresql+psycopg2://muhammad-haroon:***@localhost:5432/euro_parts_data)

# %%
import pandas as pd
TABLE_NAME = "final_daily_sales"

query = f"SELECT * FROM {TABLE_NAME} limit 1000"

# ---- Read full table into DataFrame ----
df = pd.read_sql_query(query, engine)

# ---- Save to CSV ----
df.to_csv(f"{TABLE_NAME}.csv", index=False)

print("✅ Export completed successfully")
# Out:
# ✅ Export completed successfully

# %%
TABLE_NAME = "product_template"

query = f"SELECT * FROM {TABLE_NAME} limit 1000"

# ---- Read full table into DataFrame ----
df = pd.read_sql_query(query, engine)

# ---- Save to CSV ----
#df.to_csv(f"{TABLE_NAME}.csv", index=False)
df.head()
#print("✅ Export completed successfully")
# Out:
#        id  message_main_attachment_id  sequence  categ_id  uom_id  uom_po_id  \
# 0  189500                         NaN         1         9      32         32
# 1  189501                         NaN         1         9      32         32
# 2  189502                         NaN         1        12      32         32
# 3  189503                         NaN         1         9      32         32
# 4  189504                         NaN         1         9      32         32
#
#    company_id color  create_uid  write_uid  ... rating_last_value  \
# 0           1  None           2          1  ...               0.0
# 1           1  None           2          1  ...               0.0
# 2           1  None           2          1  ...               0.0
# 3           1  None           2          1  ...               0.0
# 4           1  None           2          1  ...               0.0
#
#   base_unit_count out_of_stock_message allow_out_of_stock_order  \
# 0             1.0                 None                    False
# 1             1.0                 None                    False
# 2             1.0                 None                    False
# 3             1.0                 None                    False
# 4             1.0                 None                    False
#
#   show_availability available_threshold qty_sold views  top_selling  \
# 0              None                 5.0     None  None         None
# 1              None                 5.0     None  None         None
# 2              None                 5.0     None  None         None
# 3              None                 5.0     None  None         None
# 4              None                 5.0     None  None         None
#
#    most_viewed
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#
# [5 rows x 159 columns]

# %%
table=df

# %%
df.head()
# Out:
#        id  message_main_attachment_id  sequence  categ_id  uom_id  uom_po_id  \
# 0  189500                         NaN         1         9      32         32
# 1  189501                         NaN         1         9      32         32
# 2  189502                         NaN         1        12      32         32
# 3  189503                         NaN         1         9      32         32
# 4  189504                         NaN         1         9      32         32
#
#    company_id color  create_uid  write_uid  ... rating_last_value  \
# 0           1  None           2          1  ...               0.0
# 1           1  None           2          1  ...               0.0
# 2           1  None           2          1  ...               0.0
# 3           1  None           2          1  ...               0.0
# 4           1  None           2          1  ...               0.0
#
#   base_unit_count out_of_stock_message allow_out_of_stock_order  \
# 0             1.0                 None                    False
# 1             1.0                 None                    False
# 2             1.0                 None                    False
# 3             1.0                 None                    False
# 4             1.0                 None                    False
#
#   show_availability available_threshold qty_sold views  top_selling  \
# 0              None                 5.0     None  None         None
# 1              None                 5.0     None  None         None
# 2              None                 5.0     None  None         None
# 3              None                 5.0     None  None         None
# 4              None                 5.0     None  None         None
#
#    most_viewed
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#
# [5 rows x 159 columns]
